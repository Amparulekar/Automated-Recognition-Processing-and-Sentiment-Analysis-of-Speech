# %% [markdown]
# # CS753 2023 -- Assignment 2
#
# This assignment is due on or before **11.59 pm on April 9, 2023**. The submission portal
# on Moodle will be open until midnight on April 11th with a 5% penalty for each additional day after the 9th. This  assignment adds up to 25 points overall. This is a group assignment. You can form groups of 2-3 students.
#
# ## **Acknowledgements**
#
# * All of Task 0's ASR-related code snippets have been borrowed from the ASR Notebook at [CS224S's Assignment 4 at Stanford](https://web.stanford.edu/class/cs224s/assignments/a4/) which are, in turn, borrowed from the [SpeechBrain toolkit](https://github.com/speechbrain/speechbrain/).
#
# * SpeechBrain models are downloaded from their host site on [Huggingface](https://huggingface.co/speechbrain).
#
# * The following [SpeechBrain tutorial](https://colab.research.google.com/drive/1aFgzrUv3udM_gNJNUoLaHIm78QHtxdIz?usp=sharing#scrollTo=J6N0Fb51pFnZ) will give you a code walkthrough of how an ASR system is coded from scratch using this toolkit.
#
# ## **Dataset**
#
# We will use *HarperValleyBank (HVB)* -- a publicly-available spoken dialog corpus. Click [here](https://arxiv.org/pdf/2010.13929.pdf) for more details about the HVB corpus, how it was collected and what it is annotated for.
#
# ## **What to submit**
#
# On Moodle, you will have to submit a text file `README.txt` with answers requested for in the tasks below and a `.ipynb` file containing all your code with the following naming convention: LDAP IDs of team members delimited by `_`. E.g., `220022022_220022021.ipynb`.
#
# ## **Getting Started**
# * Make a copy of this notebook in your personal Google Drive to make edits.
# * Change your runtime type (under "Runtime") to GPU.
# * Go through all the steps in Task 0 to get set up with the first ASR task.
# * **Important:** ASR training, as in Task 0, will take close to **1.5 hours** for two epochs. Keep this in mind when scheduling your runs. You should consider saving the checkpoints from a training run if you want to use it for other experiments or for additional finetuning.

# %% [markdown]
# # Dependencies

# %%
from google.colab import drive #Mountinng the drive to colab
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# If you have any issues using `gdown`, the same data and config files are available directly via Google Drive [here](https://drive.google.com/drive/folders/1xQxvR9NRlwK-75KMd0i1y4Dy0fimTsM9).

# %%
# setup
#!gdown 1oJh0U3g_bUx6UPX4xix2UHMVHeCE_H1y
# !unzip /content/drive/MyDrive/cs753-2023-assgmt2/hvb.zip
#!mv content/data /content/
#!rm -r /content/content

#!gdown 1a0EGlsLbXnGn1xwZoSqT0tcdAQ1L2nfd # train.py
#!gdown 1yCmjRbxXRxfEN5LXdnE1Zpl8ZOIzdrAO # train.yaml
#!gdown 1KHmdcLVFI9ontvGmi5J6vfaropGYuKcr # inference.yaml

# !pip install speechbrain -q
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/data/segments/5224.wav
#   inflating: content/data/segments/7770.wav
#   inflating: content/data/segments/15016.wav
#   inflating: content/data/segments/21930.wav
#   inflating: content/data/segments/7698.wav
#   inflating: content/data/segments/12353.wav
#   inflating: content/data/segments/7926.wav
#   inflating: content/data/segments/16266.wav
#   inflating: content/data/segments/24681.wav
#   inflating: content/data/segments/20442.wav
#   inflating: content/data/segments/9689.wav
#   inflating: content/data/segments/7934.wav
#   inflating: content/data/segments/6896.wav
#   inflating: content/data/segments/12117.wav
#   inflating: content/data/segments/19455.wav
#   inflating: content/data/segments/937.wav
#   inflating: content/data/segments/16852.wav
#   inflating: content/data/segments/19350.wav
#   inflating: content/data/segments/13098.wav
#   inflating: content/data/segments/24202.wav
#   inflating: content/data/segments/2141.wav
#   inflating: content/data/segments/21039.wav
#   inflating: content/data/segments/12477.wav
#   inflating: content/data/segments/3188.wav
#   inflating: content/data/segments/25169.wav
#   inflating: content/data/segments/12972.wav
#   inflating: content/data/segments/6630.wav
#   inflating: content/data/segments/4128.wav
#   inflating: content/data/segments/13952.wav
#   inflating: content/data/segments/23949.wav
#   inflating: content/data/segments/22762.wav
#   inflating: content/data/segments/19192.wav
#   inflating: content/data/segments/1302.wav
#   inflating: content/data/segments/13756.wav
#   inflating: content/data/segments/18276.wav
#   inflating: content/data/segments/13165.wav
#   inflating: content/data/segments/871.wav
#   inflating: content/data/segments/2230.wav
#   inflating: content/data/segments/232.wav
#   inflating: content/data/segments/20748.wav
#   inflating: content/data/segments/7614.wav
#   inflating: content/data/segments/11076.wav
#   inflating: content/data/segments/10147.wav
#   inflating: content/data/segments/2777.wav
#   inflating: content/data/segments/20227.wav
#   inflating: content/data/segments/11968.wav
#   inflating: content/data/segments/5086.wav
#   inflating: content/data/segments/3099.wav
#   inflating: content/data/segments/9878.wav
#   inflating: content/data/segments/19602.wav
#   inflating: content/data/segments/7740.wav
#   inflating: content/data/segments/19720.wav
#   inflating: content/data/segments/11979.wav
#   inflating: content/data/segments/21317.wav
#   inflating: content/data/segments/19816.wav
#   inflating: content/data/segments/19224.wav
#   inflating: content/data/segments/179.wav
#   inflating: content/data/segments/3470.wav
#   inflating: content/data/segments/9242.wav
#   inflating: content/data/segments/1506.wav
#   inflating: content/data/segments/2932.wav
#   inflating: content/data/segments/25161.wav
#   inflating: content/data/segments/13341.wav
#   inflating: content/data/segments/2852.wav
#   inflating: content/data/segments/20625.wav
#   inflating: content/data/segments/21413.wav
#   inflating: content/data/segments/2766.wav
#   inflating: content/data/segments/17909.wav
#   inflating: content/data/segments/7068.wav
#   inflating: content/data/segments/6713.wav
#   inflating: content/data/segments/2575.wav
#   inflating: content/data/segments/21535.wav
#   inflating: content/data/segments/14466.wav
#   inflating: content/data/segments/22041.wav
#   inflating: content/data/segments/4662.wav
#   inflating: content/data/segments/4499.wav
#   inflating: content/data/segments/25519.wav
#   inflating: content/data/segments/5046.wav
#   inflating: content/data/segments/12995.wav
#   inflating: content/data/segments/11920.wav
#   inflating: content/data/segments/21594.wav
#   inflating: content/data/segments/19629.wav
#   inflating: content/data/segments/10120.wav
#   inflating: content/data/segments/13618.wav
#   inflating: content/data/segments/21370.wav
#   inflating: content/data/segments/21156.wav
#   inflating: content/data/segments/4326.wav
#   inflating: content/data/segments/3453.wav
#   inflating: content/data/segments/6500.wav
#   inflating: content/data/segments/8243.wav
#   inflating: content/data/segments/9537.wav
#   inflating: content/data/segments/4306.wav
#   inflating: content/data/segments/14093.wav
#   inflating: content/data/segments/9737.wav
#   inflating: content/data/segments/14629.wav
#   inflating: content/data/segments/24883.wav
#   inflating: content/data/segments/20416.wav
#   inflating: content/data/segments/11684.wav
#   inflating: content/data/segments/10319.wav
#   inflating: content/data/segments/8788.wav
#   inflating: content/data/segments/8760.wav
#   inflating: content/data/segments/7739.wav
#   inflating: content/data/segments/9636.wav
#   inflating: content/data/segments/8106.wav
#   inflating: content/data/segments/10313.wav
#   inflating: content/data/segments/10249.wav
#   inflating: content/data/segments/8769.wav
#   inflating: content/data/segments/2024.wav
#   inflating: content/data/segments/2431.wav
#   inflating: content/data/segments/11772.wav
#   inflating: content/data/segments/8023.wav
#   inflating: content/data/segments/23191.wav
#   inflating: content/data/segments/8907.wav
#   inflating: content/data/segments/15109.wav
#   inflating: content/data/segments/10688.wav
#   inflating: content/data/segments/11462.wav
#   inflating: content/data/segments/18208.wav
#   inflating: content/data/segments/16011.wav
#   inflating: content/data/segments/16938.wav
#   inflating: content/data/segments/23883.wav
#   inflating: content/data/segments/12513.wav
#   inflating: content/data/segments/1750.wav
#   inflating: content/data/segments/18973.wav
#   inflating: content/data/segments/19589.wav
#   inflating: content/data/segments/21323.wav
#   inflating: content/data/segments/2222.wav
#   inflating: content/data/segments/6561.wav
#   inflating: content/data/segments/3335.wav
#   inflating: content/data/segments/2263.wav
#   inflating: content/data/segments/8865.wav
#   inflating: content/data/segments/2471.wav
#   inflating: content/data/segments/7444.wav
#   inflating: content/data/segments/13260.wav
#   inflating: content/data/segments/15644.wav
#   inflating: content/data/segments/21695.wav
#   inflating: content/data/segments/6049.wav
#   inflating: content/data/segments/10328.wav
#   inflating: content/data/segments/19700.wav
#   inflating: content/data/segments/12337.wav
#   inflating: content/data/segments/2384.wav
#   inflating: content/data/segments/23555.wav
#   inflating: content/data/segments/23163.wav
#   inflating: content/data/segments/4605.wav
#   inflating: content/data/segments/5195.wav
#   inflating: content/data/segments/11335.wav
#   inflating: content/data/segments/23208.wav
#   inflating: content/data/segments/381.wav
#   inflating: content/data/segments/13085.wav
#   inflating: content/data/segments/7921.wav
#   inflating: content/data/segments/10354.wav
#   inflating: content/data/segments/15902.wav
#   inflating: content/data/segments/16536.wav
#   inflating: content/data/segments/12810.wav
#   inflating: content/data/segments/15105.wav
#   inflating: content/data/segments/16528.wav
#   inflating: content/data/segments/2595.wav
#   inflating: content/data/segments/18033.wav
#   inflating: content/data/segments/13307.wav
#   inflating: content/data/segments/16188.wav
#   inflating: content/data/segments/13871.wav
#   inflating: content/data/segments/22948.wav
#   inflating: content/data/segments/10179.wav
#   inflating: content/data/segments/8986.wav
#   inflating: content/data/segments/9650.wav
#   inflating: content/data/segments/1048.wav
#   inflating: content/data/segments/2640.wav
#   inflating: content/data/segments/2241.wav
#   inflating: content/data/segments/6163.wav
#   inflating: content/data/segments/17760.wav
#   inflating: content/data/segments/925.wav
#   inflating: content/data/segments/15721.wav
#   inflating: content/data/segments/4991.wav
#   inflating: content/data/segments/12956.wav
#   inflating: content/data/segments/6359.wav
#   inflating: content/data/segments/2368.wav
#   inflating: content/data/segments/4187.wav
#   inflating: content/data/segments/25421.wav
#   inflating: content/data/segments/6528.wav
#   inflating: content/data/segments/25039.wav
#   inflating: content/data/segments/16064.wav
#   inflating: content/data/segments/317.wav
#   inflating: content/data/segments/1528.wav
#   inflating: content/data/segments/959.wav
#   inflating: content/data/segments/5874.wav
#   inflating: content/data/segments/11123.wav
#   inflating: content/data/segments/14941.wav
#   inflating: content/data/segments/18329.wav
#   inflating: content/data/segments/20182.wav
#   inflating: content/data/segments/7895.wav
#   inflating: content/data/segments/13045.wav
#   inflating: content/data/segments/3716.wav
#   inflating: content/data/segments/21399.wav
#   inflating: content/data/segments/19525.wav
#   inflating: content/data/segments/15206.wav
#   inflating: content/data/segments/1549.wav
#   inflating: content/data/segments/5450.wav
#   inflating: content/data/segments/21166.wav
#   inflating: content/data/segments/13279.wav
#   inflating: content/data/segments/13942.wav
#   inflating: content/data/segments/12218.wav
#   inflating: content/data/segments/18164.wav
#   inflating: content/data/segments/7011.wav
#   inflating: content/data/segments/20722.wav
#   inflating: content/data/segments/11734.wav
#   inflating: content/data/segments/9445.wav
#   inflating: content/data/segments/3187.wav
#   inflating: content/data/segments/5995.wav
#   inflating: content/data/segments/25236.wav
#   inflating: content/data/segments/19597.wav
#   inflating: content/data/segments/11331.wav
#   inflating: content/data/segments/4409.wav
#   inflating: content/data/segments/5597.wav
#   inflating: content/data/segments/1908.wav
#   inflating: content/data/segments/287.wav
#   inflating: content/data/segments/23969.wav
#   inflating: content/data/segments/24581.wav
#   inflating: content/data/segments/14329.wav
#   inflating: content/data/segments/8967.wav
#   inflating: content/data/segments/15936.wav
#   inflating: content/data/segments/307.wav
#   inflating: content/data/segments/1068.wav
#   inflating: content/data/segments/23458.wav
#   inflating: content/data/segments/8470.wav
#   inflating: content/data/segments/3577.wav
#   inflating: content/data/segments/7116.wav
#   inflating: content/data/segments/24075.wav
#   inflating: content/data/segments/7128.wav
#   inflating: content/data/segments/24753.wav
#   inflating: content/data/segments/7759.wav
#   inflating: content/data/segments/2770.wav
#   inflating: content/data/segments/23655.wav
#   inflating: content/data/segments/24552.wav
#   inflating: content/data/segments/22052.wav
#   inflating: content/data/segments/7701.wav
#   inflating: content/data/segments/9390.wav
#   inflating: content/data/segments/21219.wav
#   inflating: content/data/segments/18812.wav
#   inflating: content/data/segments/16486.wav
#   inflating: content/data/segments/15872.wav
#   inflating: content/data/segments/5214.wav
#   inflating: content/data/segments/5319.wav
#   inflating: content/data/segments/2571.wav
#   inflating: content/data/segments/13061.wav
#   inflating: content/data/segments/23243.wav
#   inflating: content/data/segments/8149.wav
#   inflating: content/data/segments/10298.wav
#   inflating: content/data/segments/5596.wav
#   inflating: content/data/segments/12611.wav
#   inflating: content/data/segments/18832.wav
#   inflating: content/data/segments/25019.wav
#   inflating: content/data/segments/24071.wav
#   inflating: content/data/segments/14904.wav
#   inflating: content/data/segments/8564.wav
#   inflating: content/data/segments/16667.wav
#   inflating: content/data/segments/25170.wav
#   inflating: content/data/segments/13122.wav
#   inflating: content/data/segments/21830.wav
#   inflating: content/data/segments/5106.wav
#   inflating: content/data/segments/14811.wav
#   inflating: content/data/segments/19851.wav
#   inflating: content/data/segments/14512.wav
#   inflating: content/data/segments/683.wav
#   inflating: content/data/segments/7985.wav
#   inflating: content/data/segments/14897.wav
#   inflating: content/data/segments/9409.wav
#   inflating: content/data/segments/11620.wav
#   inflating: content/data/segments/8977.wav
#   inflating: content/data/segments/19491.wav
#   inflating: content/data/segments/16462.wav
#   inflating: content/data/segments/23919.wav
#   inflating: content/data/segments/19013.wav
#   inflating: content/data/segments/2516.wav
#   inflating: content/data/segments/18246.wav
#   inflating: content/data/segments/18857.wav
#   inflating: content/data/segments/15298.wav
#   inflating: content/data/segments/9324.wav
#   inflating: content/data/segments/3883.wav
#   inflating: content/data/segments/24249.wav
#   inflating: content/data/segments/21782.wav
#   inflating: content/data/segments/15320.wav
#   inflating: content/data/segments/6939.wav
#   inflating: content/data/segments/19942.wav
#   inflating: content/data/segments/10446.wav
#   inflating: content/data/segments/1107.wav
#   inflating: content/data/segments/14940.wav
#   inflating: content/data/segments/25221.wav
#   inflating: content/data/segments/14801.wav
#   inflating: content/data/segments/18393.wav
#   inflating: content/data/segments/19341.wav
#   inflating: content/data/segments/2639.wav
#   inflating: content/data/segments/19933.wav
#   inflating: content/data/segments/7674.wav
#   inflating: content/data/segments/15526.wav
#   inflating: content/data/segments/7706.wav
#   inflating: content/data/segments/17097.wav
#   inflating: content/data/segments/11808.wav
#   inflating: content/data/segments/25036.wav
#   inflating: content/data/segments/3734.wav
#   inflating: content/data/segments/16351.wav
#   inflating: content/data/segments/2382.wav
#   inflating: content/data/segments/22585.wav
#   inflating: content/data/segments/11662.wav
#   inflating: content/data/segments/22556.wav
#   inflating: content/data/segments/9733.wav
#   inflating: content/data/segments/22120.wav
#   inflating: content/data/segments/5797.wav
#   inflating: content/data/segments/7671.wav
#   inflating: content/data/segments/8115.wav
#   inflating: content/data/segments/9914.wav
#   inflating: content/data/segments/1454.wav
#   inflating: content/data/segments/20579.wav
#   inflating: content/data/segments/12677.wav
#   inflating: content/data/segments/15250.wav
#   inflating: content/data/segments/18505.wav
#   inflating: content/data/segments/13966.wav
#   inflating: content/data/segments/1561.wav
#   inflating: content/data/segments/9962.wav
#   inflating: content/data/segments/19386.wav
#   inflating: content/data/segments/6335.wav
#   inflating: content/data/segments/25379.wav
#   inflating: content/data/segments/13327.wav
#   inflating: content/data/segments/397.wav
#   inflating: content/data/segments/15908.wav
#   inflating: content/data/segments/10709.wav
#   inflating: content/data/segments/137.wav
#   inflating: content/data/segments/8147.wav
#   inflating: content/data/segments/1220.wav
#   inflating: content/data/segments/9900.wav
#   inflating: content/data/segments/5870.wav
#   inflating: content/data/segments/21580.wav
#   inflating: content/data/segments/14304.wav
#   inflating: content/data/segments/1978.wav
#   inflating: content/data/segments/5621.wav
#   inflating: content/data/segments/16810.wav
#   inflating: content/data/segments/17573.wav
#   inflating: content/data/segments/10221.wav
#   inflating: content/data/segments/22575.wav
#   inflating: content/data/segments/22747.wav
#   inflating: content/data/segments/2183.wav
#   inflating: content/data/segments/16899.wav
#   inflating: content/data/segments/8213.wav
#   inflating: content/data/segments/11837.wav
#   inflating: content/data/segments/14389.wav
#   inflating: content/data/segments/16278.wav
#   inflating: content/data/segments/22739.wav
#   inflating: content/data/segments/14624.wav
#   inflating: content/data/segments/24490.wav
#   inflating: content/data/segments/8560.wav
#   inflating: content/data/segments/1413.wav
#   inflating: content/data/segments/840.wav
#   inflating: content/data/segments/10241.wav
#   inflating: content/data/segments/6478.wav
#   inflating: content/data/segments/10444.wav
#   inflating: content/data/segments/424.wav
#   inflating: content/data/segments/13139.wav
#   inflating: content/data/segments/5481.wav
#   inflating: content/data/segments/24079.wav
#   inflating: content/data/segments/12076.wav
#   inflating: content/data/segments/9102.wav
#   inflating: content/data/segments/23346.wav
#   inflating: content/data/segments/5516.wav
#   inflating: content/data/segments/18432.wav
#   inflating: content/data/segments/22735.wav
#   inflating: content/data/segments/6759.wav
#   inflating: content/data/segments/5019.wav
#   inflating: content/data/segments/17614.wav
#   inflating: content/data/segments/19837.wav
#   inflating: content/data/segments/7821.wav
#   inflating: content/data/segments/24157.wav
#   inflating: content/data/segments/21855.wav
#   inflating: content/data/segments/12149.wav
#   inflating: content/data/segments/24171.wav
#   inflating: content/data/segments/25713.wav
#   inflating: content/data/segments/9923.wav
#   inflating: content/data/segments/10288.wav
#   inflating: content/data/segments/17284.wav
#   inflating: content/data/segments/4684.wav
#   inflating: content/data/segments/17207.wav
#   inflating: content/data/segments/12293.wav
#   inflating: content/data/segments/4447.wav
#   inflating: content/data/segments/23046.wav
#   inflating: content/data/segments/13909.wav
#   inflating: content/data/segments/22379.wav
#   inflating: content/data/segments/22943.wav
#   inflating: content/data/segments/20822.wav
#   inflating: content/data/segments/20724.wav
#   inflating: content/data/segments/15404.wav
#   inflating: content/data/segments/6315.wav
#   inflating: content/data/segments/17908.wav
#   inflating: content/data/segments/12699.wav
#   inflating: content/data/segments/17356.wav
#   inflating: content/data/segments/9006.wav
#   inflating: content/data/segments/13546.wav
#   inflating: content/data/segments/154.wav
#   inflating: content/data/segments/7396.wav
#   inflating: content/data/segments/10587.wav
#   inflating: content/data/segments/11519.wav
#   inflating: content/data/segments/2756.wav
#   inflating: content/data/segments/3294.wav
#   inflating: content/data/segments/12065.wav
#   inflating: content/data/segments/2242.wav
#   inflating: content/data/segments/11999.wav
#   inflating: content/data/segments/21043.wav
#   inflating: content/data/segments/10062.wav
#   inflating: content/data/segments/15651.wav
#   inflating: content/data/segments/505.wav
#   inflating: content/data/segments/5820.wav
#   inflating: content/data/segments/13225.wav
#   inflating: content/data/segments/3818.wav
#   inflating: content/data/segments/18814.wav
#   inflating: content/data/segments/6952.wav
#   inflating: content/data/segments/9932.wav
#   inflating: content/data/segments/16068.wav
#   inflating: content/data/segments/6495.wav
#   inflating: content/data/segments/5774.wav
#   inflating: content/data/segments/4966.wav
#   inflating: content/data/segments/18418.wav
#   inflating: content/data/segments/17203.wav
#   inflating: content/data/segments/18071.wav
#   inflating: content/data/segments/25453.wav
#   inflating: content/data/segments/3248.wav
#   inflating: content/data/segments/11657.wav
#   inflating: content/data/segments/8167.wav
#   inflating: content/data/segments/6158.wav
#   inflating: content/data/segments/20408.wav
#   inflating: content/data/segments/5099.wav
#   inflating: content/data/segments/22584.wav
#   inflating: content/data/segments/8783.wav
#   inflating: content/data/segments/21394.wav
#   inflating: content/data/segments/17859.wav
#   inflating: content/data/segments/19070.wav
#   inflating: content/data/segments/5799.wav
#   inflating: content/data/segments/6235.wav
#   inflating: content/data/segments/12341.wav
#   inflating: content/data/segments/21347.wav
#   inflating: content/data/segments/19975.wav
#   inflating: content/data/segments/23639.wav
#   inflating: content/data/segments/11919.wav
#   inflating: content/data/segments/23129.wav
#   inflating: content/data/segments/10117.wav
#   inflating: content/data/segments/13539.wav
#   inflating: content/data/segments/16856.wav
#   inflating: content/data/segments/14152.wav
#   inflating: content/data/segments/14676.wav
#   inflating: content/data/segments/7306.wav
#   inflating: content/data/segments/19916.wav
#   inflating: content/data/segments/16974.wav
#   inflating: content/data/segments/3065.wav
#   inflating: content/data/segments/4197.wav
#   inflating: content/data/segments/21577.wav
#   inflating: content/data/segments/12333.wav
#   inflating: content/data/segments/17799.wav
#   inflating: content/data/segments/25429.wav
#   inflating: content/data/segments/20682.wav
#   inflating: content/data/segments/18652.wav
#   inflating: content/data/segments/25018.wav
#   inflating: content/data/segments/24951.wav
#   inflating: content/data/segments/12632.wav
#   inflating: content/data/segments/5395.wav
#   inflating: content/data/segments/311.wav
#   inflating: content/data/segments/15475.wav
#   inflating: content/data/segments/16374.wav
#   inflating: content/data/segments/10035.wav
#   inflating: content/data/segments/24236.wav
#   inflating: content/data/segments/11884.wav
#   inflating: content/data/segments/10266.wav
#   inflating: content/data/segments/12390.wav
#   inflating: content/data/segments/19958.wav
#   inflating: content/data/segments/24618.wav
#   inflating: content/data/segments/15173.wav
#   inflating: content/data/segments/16364.wav
#   inflating: content/data/segments/2700.wav
#   inflating: content/data/segments/24048.wav
#   inflating: content/data/segments/25599.wav
#   inflating: content/data/segments/10435.wav
#   inflating: content/data/segments/406.wav
#   inflating: content/data/segments/8996.wav
#   inflating: content/data/segments/25728.wav
#   inflating: content/data/segments/3042.wav
#   inflating: content/data/segments/20856.wav
#   inflating: content/data/segments/10546.wav
#   inflating: content/data/segments/14434.wav
#   inflating: content/data/segments/6139.wav
#   inflating: content/data/segments/20175.wav
#   inflating: content/data/segments/10099.wav
#   inflating: content/data/segments/8786.wav
#   inflating: content/data/segments/513.wav
#   inflating: content/data/segments/1727.wav
#   inflating: content/data/segments/12272.wav
#   inflating: content/data/segments/15632.wav
#   inflating: content/data/segments/20123.wav
#   inflating: content/data/segments/24762.wav
#   inflating: content/data/segments/14975.wav
#   inflating: content/data/segments/17406.wav
#   inflating: content/data/segments/22049.wav
#   inflating: content/data/segments/24126.wav
#   inflating: content/data/segments/23701.wav
#   inflating: content/data/segments/4551.wav
#   inflating: content/data/segments/7025.wav
#   inflating: content/data/segments/19123.wav
#   inflating: content/data/segments/22140.wav
#   inflating: content/data/segments/22376.wav
#   inflating: content/data/segments/5283.wav
#   inflating: content/data/segments/14087.wav
#   inflating: content/data/segments/17477.wav
#   inflating: content/data/segments/18771.wav
#   inflating: content/data/segments/23932.wav
#   inflating: content/data/segments/4230.wav
#   inflating: content/data/segments/14256.wav
#   inflating: content/data/segments/14469.wav
#   inflating: content/data/segments/7869.wav
#   inflating: content/data/segments/22497.wav
#   inflating: content/data/segments/22995.wav
#   inflating: content/data/segments/25049.wav
#   inflating: content/data/segments/12981.wav
#   inflating: content/data/segments/3961.wav
#   inflating: content/data/segments/17072.wav
#   inflating: content/data/segments/18782.wav
#   inflating: content/data/segments/1427.wav
#   inflating: content/data/segments/16346.wav
#   inflating: content/data/segments/774.wav
#   inflating: content/data/segments/24277.wav
#   inflating: content/data/segments/8637.wav
#   inflating: content/data/segments/4483.wav
#   inflating: content/data/segments/18270.wav
#   inflating: content/data/segments/4564.wav
#   inflating: content/data/segments/23589.wav
#   inflating: content/data/segments/18451.wav
#   inflating: content/data/segments/16984.wav
#   inflating: content/data/segments/13734.wav
#   inflating: content/data/segments/17618.wav
#   inflating: content/data/segments/2469.wav
#   inflating: content/data/segments/13199.wav
#   inflating: content/data/segments/19233.wav
#   inflating: content/data/segments/3131.wav
#   inflating: content/data/segments/18993.wav
#   inflating: content/data/segments/10632.wav
#   inflating: content/data/segments/3396.wav
#   inflating: content/data/segments/12990.wav
#   inflating: content/data/segments/1809.wav
#   inflating: content/data/segments/17308.wav
#   inflating: content/data/segments/23355.wav
#   inflating: content/data/segments/18382.wav
#   inflating: content/data/segments/9154.wav
#   inflating: content/data/segments/11531.wav
#   inflating: content/data/segments/21760.wav
#   inflating: content/data/segments/17544.wav
#   inflating: content/data/segments/7940.wav
#   inflating: content/data/segments/218.wav
#   inflating: content/data/segments/4844.wav
#   inflating: content/data/segments/12509.wav
#   inflating: content/data/segments/2913.wav
#   inflating: content/data/segments/21178.wav
#   inflating: content/data/segments/17366.wav
#   inflating: content/data/segments/3902.wav
#   inflating: content/data/segments/3180.wav
#   inflating: content/data/segments/3584.wav
#   inflating: content/data/segments/87.wav
#   inflating: content/data/segments/2784.wav
#   inflating: content/data/segments/8984.wav
#   inflating: content/data/segments/4036.wav
#   inflating: content/data/segments/14417.wav
#   inflating: content/data/segments/9728.wav
#   inflating: content/data/segments/24842.wav
#   inflating: content/data/segments/766.wav
#   inflating: content/data/segments/7588.wav
#   inflating: content/data/segments/21905.wav
#   inflating: content/data/segments/14720.wav
#   inflating: content/data/segments/14471.wav
#   inflating: content/data/segments/15893.wav
#   inflating: content/data/segments/24102.wav
#   inflating: content/data/segments/20000.wav
#   inflating: content/data/segments/11485.wav
#   inflating: content/data/segments/5500.wav
#   inflating: content/data/segments/11569.wav
#   inflating: content/data/segments/2631.wav
#   inflating: content/data/segments/19709.wav
#   inflating: content/data/segments/1509.wav
#   inflating: content/data/segments/20757.wav
#   inflating: content/data/segments/685.wav
#   inflating: content/data/segments/9987.wav
#   inflating: content/data/segments/2723.wav
#   inflating: content/data/segments/14910.wav
#   inflating: content/data/segments/831.wav
#   inflating: content/data/segments/13339.wav
#   inflating: content/data/segments/17209.wav
#   inflating: content/data/segments/13477.wav
#   inflating: content/data/segments/7213.wav
#   inflating: content/data/segments/5031.wav
#   inflating: content/data/segments/16646.wav
#   inflating: content/data/segments/21712.wav
#   inflating: content/data/segments/23373.wav
#   inflating: content/data/segments/22370.wav
#   inflating: content/data/segments/15823.wav
#   inflating: content/data/segments/15851.wav
#   inflating: content/data/segments/15745.wav
#   inflating: content/data/segments/10217.wav
#   inflating: content/data/segments/9679.wav
#   inflating: content/data/segments/23935.wav
#   inflating: content/data/segments/3189.wav
#   inflating: content/data/segments/3301.wav
#   inflating: content/data/segments/12367.wav
#   inflating: content/data/segments/19366.wav
#   inflating: content/data/segments/9993.wav
#   inflating: content/data/segments/18031.wav
#   inflating: content/data/segments/911.wav
#   inflating: content/data/segments/15655.wav
#   inflating: content/data/segments/829.wav
#   inflating: content/data/segments/993.wav
#   inflating: content/data/segments/7451.wav
#   inflating: content/data/segments/2978.wav
#   inflating: content/data/segments/16715.wav
#   inflating: content/data/segments/16508.wav
#   inflating: content/data/segments/19734.wav
#   inflating: content/data/segments/21343.wav
#   inflating: content/data/segments/998.wav
#   inflating: content/data/segments/5284.wav
#   inflating: content/data/segments/23268.wav
#   inflating: content/data/segments/13739.wav
#   inflating: content/data/segments/5940.wav
#   inflating: content/data/segments/10613.wav
#   inflating: content/data/segments/16475.wav
#   inflating: content/data/segments/15996.wav
#   inflating: content/data/segments/8942.wav
#   inflating: content/data/segments/11033.wav
#   inflating: content/data/segments/54.wav
#   inflating: content/data/segments/15484.wav
#   inflating: content/data/segments/8226.wav
#   inflating: content/data/segments/2606.wav
#   inflating: content/data/segments/23357.wav
#   inflating: content/data/segments/20454.wav
#   inflating: content/data/segments/18457.wav
#   inflating: content/data/segments/416.wav
#   inflating: content/data/segments/13601.wav
#   inflating: content/data/segments/289.wav
#   inflating: content/data/segments/18470.wav
#   inflating: content/data/segments/15704.wav
#   inflating: content/data/segments/14287.wav
#   inflating: content/data/segments/23478.wav
#   inflating: content/data/segments/11874.wav
#   inflating: content/data/segments/24407.wav
#   inflating: content/data/segments/9082.wav
#   inflating: content/data/segments/19826.wav
#   inflating: content/data/segments/12026.wav
#   inflating: content/data/segments/10411.wav
#   inflating: content/data/segments/11260.wav
#   inflating: content/data/segments/25432.wav
#   inflating: content/data/segments/18183.wav
#   inflating: content/data/segments/14690.wav
#   inflating: content/data/segments/18135.wav
#   inflating: content/data/segments/2029.wav
#   inflating: content/data/segments/2419.wav
#   inflating: content/data/segments/19407.wav
#   inflating: content/data/segments/24315.wav
#   inflating: content/data/segments/3423.wav
#   inflating: content/data/segments/23579.wav
#   inflating: content/data/segments/9046.wav
#   inflating: content/data/segments/13972.wav
#   inflating: content/data/segments/2893.wav
#   inflating: content/data/segments/23464.wav
#   inflating: content/data/segments/9997.wav
#   inflating: content/data/segments/13903.wav
#   inflating: content/data/segments/5999.wav
#   inflating: content/data/segments/17848.wav
#   inflating: content/data/segments/17469.wav
#   inflating: content/data/segments/10096.wav
#   inflating: content/data/segments/6395.wav
#   inflating: content/data/segments/25583.wav
#   inflating: content/data/segments/20467.wav
#   inflating: content/data/segments/23607.wav
#   inflating: content/data/segments/3856.wav
#   inflating: content/data/segments/22001.wav
#   inflating: content/data/segments/15057.wav
#   inflating: content/data/segments/6641.wav
#   inflating: content/data/segments/847.wav
#   inflating: content/data/segments/25455.wav
#   inflating: content/data/segments/1146.wav
#   inflating: content/data/segments/7780.wav
#   inflating: content/data/segments/7403.wav
#   inflating: content/data/segments/10906.wav
#   inflating: content/data/segments/5071.wav
#   inflating: content/data/segments/960.wav
#   inflating: content/data/segments/13105.wav
#   inflating: content/data/segments/15317.wav
#   inflating: content/data/segments/10067.wav
#   inflating: content/data/segments/25586.wav
#   inflating: content/data/segments/5057.wav
#   inflating: content/data/segments/1622.wav
#   inflating: content/data/segments/15290.wav
#   inflating: content/data/segments/19102.wav
#   inflating: content/data/segments/16230.wav
#   inflating: content/data/segments/22000.wav
#   inflating: content/data/segments/20812.wav
#   inflating: content/data/segments/24551.wav
#   inflating: content/data/segments/24780.wav
#   inflating: content/data/segments/17875.wav
#   inflating: content/data/segments/1905.wav
#   inflating: content/data/segments/20355.wav
#   inflating: content/data/segments/271.wav
#   inflating: content/data/segments/15111.wav
#   inflating: content/data/segments/13569.wav
#   inflating: content/data/segments/3672.wav
#   inflating: content/data/segments/20533.wav
#   inflating: content/data/segments/20290.wav
#   inflating: content/data/segments/17560.wav
#   inflating: content/data/segments/3288.wav
#   inflating: content/data/segments/288.wav
#   inflating: content/data/segments/14995.wav
#   inflating: content/data/segments/10569.wav
#   inflating: content/data/segments/17961.wav
#   inflating: content/data/segments/14292.wav
#   inflating: content/data/segments/23598.wav
#   inflating: content/data/segments/18321.wav
#   inflating: content/data/segments/2881.wav
#   inflating: content/data/segments/13273.wav
#   inflating: content/data/segments/18335.wav
#   inflating: content/data/segments/1700.wav
#   inflating: content/data/segments/8137.wav
#   inflating: content/data/segments/8694.wav
#   inflating: content/data/segments/25514.wav
#   inflating: content/data/segments/15550.wav
#   inflating: content/data/segments/6925.wav
#   inflating: content/data/segments/21548.wav
#   inflating: content/data/segments/6654.wav
#   inflating: content/data/segments/18327.wav
#   inflating: content/data/segments/1816.wav
#   inflating: content/data/segments/1555.wav
#   inflating: content/data/segments/21710.wav
#   inflating: content/data/segments/823.wav
#   inflating: content/data/segments/24457.wav
#   inflating: content/data/segments/21365.wav
#   inflating: content/data/segments/9157.wav
#   inflating: content/data/segments/17109.wav
#   inflating: content/data/segments/13941.wav
#   inflating: content/data/segments/3379.wav
#   inflating: content/data/segments/8382.wav
#   inflating: content/data/segments/20010.wav
#   inflating: content/data/segments/15529.wav
#   inflating: content/data/segments/24768.wav
#   inflating: content/data/segments/17257.wav
#   inflating: content/data/segments/7019.wav
#   inflating: content/data/segments/13733.wav
#   inflating: content/data/segments/2327.wav
#   inflating: content/data/segments/10495.wav
#   inflating: content/data/segments/3610.wav
#   inflating: content/data/segments/18676.wav
#   inflating: content/data/segments/20684.wav
#   inflating: content/data/segments/14218.wav
#   inflating: content/data/segments/19724.wav
#   inflating: content/data/segments/1910.wav
#   inflating: content/data/segments/18956.wav
#   inflating: content/data/segments/17657.wav
#   inflating: content/data/segments/24017.wav
#   inflating: content/data/segments/21279.wav
#   inflating: content/data/segments/19681.wav
#   inflating: content/data/segments/6178.wav
#   inflating: content/data/segments/8910.wav
#   inflating: content/data/segments/22071.wav
#   inflating: content/data/segments/1600.wav
#   inflating: content/data/segments/4611.wav
#   inflating: content/data/segments/18874.wav
#   inflating: content/data/segments/14061.wav
#   inflating: content/data/segments/3384.wav
#   inflating: content/data/segments/15810.wav
#   inflating: content/data/segments/19919.wav
#   inflating: content/data/segments/7772.wav
#   inflating: content/data/segments/25085.wav
#   inflating: content/data/segments/18209.wav
#   inflating: content/data/segments/21789.wav
#   inflating: content/data/segments/15237.wav
#   inflating: content/data/segments/19695.wav
#   inflating: content/data/segments/21977.wav
#   inflating: content/data/segments/8635.wav
#   inflating: content/data/segments/5085.wav
#   inflating: content/data/segments/5008.wav
#   inflating: content/data/segments/17417.wav
#   inflating: content/data/segments/25050.wav
#   inflating: content/data/segments/9227.wav
#   inflating: content/data/segments/7408.wav
#   inflating: content/data/segments/4692.wav
#   inflating: content/data/segments/20405.wav
#   inflating: content/data/segments/17224.wav
#   inflating: content/data/segments/5089.wav
#   inflating: content/data/segments/25240.wav
#   inflating: content/data/segments/4727.wav
#   inflating: content/data/segments/12886.wav
#   inflating: content/data/segments/9186.wav
#   inflating: content/data/segments/11397.wav
#   inflating: content/data/segments/21560.wav
#   inflating: content/data/segments/22084.wav
#   inflating: content/data/segments/12230.wav
#   inflating: content/data/segments/20829.wav
#   inflating: content/data/segments/21792.wav
#   inflating: content/data/segments/3217.wav
#   inflating: content/data/segments/2038.wav
#   inflating: content/data/segments/21726.wav
#   inflating: content/data/segments/22328.wav
#   inflating: content/data/segments/10338.wav
#   inflating: content/data/segments/1541.wav
#   inflating: content/data/segments/17681.wav
#   inflating: content/data/segments/11049.wav
#   inflating: content/data/segments/20023.wav
#   inflating: content/data/segments/1766.wav
#   inflating: content/data/segments/14923.wav
#   inflating: content/data/segments/14145.wav
#   inflating: content/data/segments/13757.wav
#   inflating: content/data/segments/20544.wav
#   inflating: content/data/segments/19477.wav
#   inflating: content/data/segments/4802.wav
#   inflating: content/data/segments/11572.wav
#   inflating: content/data/segments/20702.wav
#   inflating: content/data/segments/15725.wav
#   inflating: content/data/segments/22075.wav
#   inflating: content/data/segments/17753.wav
#   inflating: content/data/segments/3746.wav
#   inflating: content/data/segments/8575.wav
#   inflating: content/data/segments/14645.wav
#   inflating: content/data/segments/9825.wav
#   inflating: content/data/segments/3986.wav
#   inflating: content/data/segments/17910.wav
#   inflating: content/data/segments/1476.wav
#   inflating: content/data/segments/8477.wav
#   inflating: content/data/segments/23776.wav
#   inflating: content/data/segments/1752.wav
#   inflating: content/data/segments/10719.wav
#   inflating: content/data/segments/12067.wav
#   inflating: content/data/segments/12536.wav
#   inflating: content/data/segments/12920.wav
#   inflating: content/data/segments/7680.wav
#   inflating: content/data/segments/21384.wav
#   inflating: content/data/segments/11949.wav
#   inflating: content/data/segments/310.wav
#   inflating: content/data/segments/679.wav
#   inflating: content/data/segments/18010.wav
#   inflating: content/data/segments/14432.wav
#   inflating: content/data/segments/22895.wav
#   inflating: content/data/segments/13412.wav
#   inflating: content/data/segments/14244.wav
#   inflating: content/data/segments/10440.wav
#   inflating: content/data/segments/22710.wav
#   inflating: content/data/segments/8473.wav
#   inflating: content/data/segments/8905.wav
#   inflating: content/data/segments/14366.wav
#   inflating: content/data/segments/12951.wav
#   inflating: content/data/segments/5993.wav
#   inflating: content/data/segments/11011.wav
#   inflating: content/data/segments/5892.wav
#   inflating: content/data/segments/20381.wav
#   inflating: content/data/segments/18408.wav
#   inflating: content/data/segments/4507.wav
#   inflating: content/data/segments/23180.wav
#   inflating: content/data/segments/16936.wav
#   inflating: content/data/segments/9183.wav
#   inflating: content/data/segments/18468.wav
#   inflating: content/data/segments/24688.wav
#   inflating: content/data/segments/18431.wav
#   inflating: content/data/segments/12184.wav
#   inflating: content/data/segments/17091.wav
#   inflating: content/data/segments/11316.wav
#   inflating: content/data/segments/1737.wav
#   inflating: content/data/segments/16752.wav
#   inflating: content/data/segments/7161.wav
#   inflating: content/data/segments/6270.wav
#   inflating: content/data/segments/22066.wav
#   inflating: content/data/segments/14966.wav
#   inflating: content/data/segments/11528.wav
#   inflating: content/data/segments/19460.wav
#   inflating: content/data/segments/2783.wav
#   inflating: content/data/segments/24469.wav
#   inflating: content/data/segments/11050.wav
#   inflating: content/data/segments/824.wav
#   inflating: content/data/segments/2997.wav
#   inflating: content/data/segments/8267.wav
#   inflating: content/data/segments/19753.wav
#   inflating: content/data/segments/8261.wav
#   inflating: content/data/segments/12135.wav
#   inflating: content/data/segments/14695.wav
#   inflating: content/data/segments/9038.wav
#   inflating: content/data/segments/1426.wav
#   inflating: content/data/segments/11238.wav
#   inflating: content/data/segments/791.wav
#   inflating: content/data/segments/16388.wav
#   inflating: content/data/segments/12770.wav
#   inflating: content/data/segments/22338.wav
#   inflating: content/data/segments/24375.wav
#   inflating: content/data/segments/9146.wav
#   inflating: content/data/segments/19810.wav
#   inflating: content/data/segments/11666.wav
#   inflating: content/data/segments/12267.wav
#   inflating: content/data/segments/12704.wav
#   inflating: content/data/segments/8340.wav
#   inflating: content/data/segments/11928.wav
#   inflating: content/data/segments/18965.wav
#   inflating: content/data/segments/14236.wav
#   inflating: content/data/segments/18006.wav
#   inflating: content/data/segments/17572.wav
#   inflating: content/data/segments/11748.wav
#   inflating: content/data/segments/16348.wav
#   inflating: content/data/segments/16526.wav
#   inflating: content/data/segments/12420.wav
#   inflating: content/data/segments/4180.wav
#   inflating: content/data/segments/14328.wav
#   inflating: content/data/segments/7274.wav
#   inflating: content/data/segments/24788.wav
#   inflating: content/data/segments/1170.wav
#   inflating: content/data/segments/25041.wav
#   inflating: content/data/segments/24971.wav
#   inflating: content/data/segments/21318.wav
#   inflating: content/data/segments/13981.wav
#   inflating: content/data/segments/1093.wav
#   inflating: content/data/segments/17722.wav
#   inflating: content/data/segments/9105.wav
#   inflating: content/data/segments/1491.wav
#   inflating: content/data/segments/15657.wav
#   inflating: content/data/segments/21024.wav
#   inflating: content/data/segments/7427.wav
#   inflating: content/data/segments/11323.wav
#   inflating: content/data/segments/20847.wav
#   inflating: content/data/segments/6319.wav
#   inflating: content/data/segments/7359.wav
#   inflating: content/data/segments/3632.wav
#   inflating: content/data/segments/7907.wav
#   inflating: content/data/segments/435.wav
#   inflating: content/data/segments/22157.wav
#   inflating: content/data/segments/6977.wav
#   inflating: content/data/segments/24747.wav
#   inflating: content/data/segments/7695.wav
#   inflating: content/data/segments/6876.wav
#   inflating: content/data/segments/17237.wav
#   inflating: content/data/segments/15684.wav
#   inflating: content/data/segments/10282.wav
#   inflating: content/data/segments/8705.wav
#   inflating: content/data/segments/14548.wav
#   inflating: content/data/segments/11728.wav
#   inflating: content/data/segments/25699.wav
#   inflating: content/data/segments/17601.wav
#   inflating: content/data/segments/24286.wav
#   inflating: content/data/segments/1276.wav
#   inflating: content/data/segments/11250.wav
#   inflating: content/data/segments/15445.wav
#   inflating: content/data/segments/20163.wav
#   inflating: content/data/segments/4429.wav
#   inflating: content/data/segments/1436.wav
#   inflating: content/data/segments/4975.wav
#   inflating: content/data/segments/6599.wav
#   inflating: content/data/segments/25198.wav
#   inflating: content/data/segments/16840.wav
#   inflating: content/data/segments/4292.wav
#   inflating: content/data/segments/10457.wav
#   inflating: content/data/segments/3138.wav
#   inflating: content/data/segments/13792.wav
#   inflating: content/data/segments/20114.wav
#   inflating: content/data/segments/18357.wav
#   inflating: content/data/segments/21879.wav
#   inflating: content/data/segments/22128.wav
#   inflating: content/data/segments/3534.wav
#   inflating: content/data/segments/16245.wav
#   inflating: content/data/segments/7775.wav
#   inflating: content/data/segments/6831.wav
#   inflating: content/data/segments/8503.wav
#   inflating: content/data/segments/13736.wav
#   inflating: content/data/segments/7548.wav
#   inflating: content/data/segments/23359.wav
#   inflating: content/data/segments/21515.wav
#   inflating: content/data/segments/20776.wav
#   inflating: content/data/segments/256.wav
#   inflating: content/data/segments/7834.wav
#   inflating: content/data/segments/398.wav
#   inflating: content/data/segments/18500.wav
#   inflating: content/data/segments/7368.wav
#   inflating: content/data/segments/18914.wav
#   inflating: content/data/segments/12917.wav
#   inflating: content/data/segments/10512.wav
#   inflating: content/data/segments/12839.wav
#   inflating: content/data/segments/9010.wav
#   inflating: content/data/segments/7021.wav
#   inflating: content/data/segments/22133.wav
#   inflating: content/data/segments/7811.wav
#   inflating: content/data/segments/4086.wav
#   inflating: content/data/segments/12004.wav
#   inflating: content/data/segments/21752.wav
#   inflating: content/data/segments/20372.wav
#   inflating: content/data/segments/6568.wav
#   inflating: content/data/segments/22207.wav
#   inflating: content/data/segments/15408.wav
#   inflating: content/data/segments/18743.wav
#   inflating: content/data/segments/16072.wav
#   inflating: content/data/segments/17899.wav
#   inflating: content/data/segments/23578.wav
#   inflating: content/data/segments/6262.wav
#   inflating: content/data/segments/22240.wav
#   inflating: content/data/segments/6407.wav
#   inflating: content/data/segments/20563.wav
#   inflating: content/data/segments/16916.wav
#   inflating: content/data/segments/941.wav
#   inflating: content/data/segments/24176.wav
#   inflating: content/data/segments/23329.wav
#   inflating: content/data/segments/8216.wav
#   inflating: content/data/segments/17094.wav
#   inflating: content/data/segments/12221.wav
#   inflating: content/data/segments/24118.wav
#   inflating: content/data/segments/5639.wav
#   inflating: content/data/segments/3783.wav
#   inflating: content/data/segments/11223.wav
#   inflating: content/data/segments/18848.wav
#   inflating: content/data/segments/10694.wav
#   inflating: content/data/segments/11762.wav
#   inflating: content/data/segments/12792.wav
#   inflating: content/data/segments/6223.wav
#   inflating: content/data/segments/16299.wav
#   inflating: content/data/segments/264.wav
#   inflating: content/data/segments/12033.wav
#   inflating: content/data/segments/17889.wav
#   inflating: content/data/segments/10360.wav
#   inflating: content/data/segments/19917.wav
#   inflating: content/data/segments/9270.wav
#   inflating: content/data/segments/21765.wav
#   inflating: content/data/segments/23763.wav
#   inflating: content/data/segments/7551.wav
#   inflating: content/data/segments/13999.wav
#   inflating: content/data/segments/23843.wav
#   inflating: content/data/segments/16003.wav
#   inflating: content/data/segments/17455.wav
#   inflating: content/data/segments/6987.wav
#   inflating: content/data/segments/10242.wav
#   inflating: content/data/segments/5778.wav
#   inflating: content/data/segments/18522.wav
#   inflating: content/data/segments/18376.wav
#   inflating: content/data/segments/14355.wav
# ...
#   inflating: content/data/segments/8430.wav
#   inflating: content/data/segments/12233.wav
#   inflating: content/data/segments/12941.wav
#   inflating: content/data/segments/4956.wav
#   inflating: content/data/segments/8203.wav
#   inflating: content/data/segments/14788.wav
#   inflating: content/data/segments/12807.wav
#   inflating: content/data/segments/5496.wav
#   inflating: content/data/segments/13057.wav
#   inflating: content/data/segments/1802.wav
#   inflating: content/data/segments/4943.wav
#   inflating: content/data/segments/6581.wav
#   inflating: content/data/segments/18983.wav
#   inflating: content/data/segments/15427.wav
#   inflating: content/data/segments/17871.wav
#   inflating: content/data/segments/1269.wav
#   inflating: content/data/segments/17074.wav
#   inflating: content/data/segments/6402.wav
#   inflating: content/data/segments/10963.wav
#   inflating: content/data/segments/24848.wav
#   inflating: content/data/segments/16919.wav
#   inflating: content/data/segments/4504.wav
#   inflating: content/data/segments/14550.wav
#   inflating: content/data/segments/15646.wav
#   inflating: content/data/segments/23724.wav
#   inflating: content/data/segments/16576.wav
#   inflating: content/data/segments/16027.wav
#   inflating: content/data/segments/13284.wav
#   inflating: content/data/segments/9651.wav
#   inflating: content/data/segments/21646.wav
#   inflating: content/data/segments/23055.wav
#   inflating: content/data/segments/15913.wav
#   inflating: content/data/segments/2867.wav
#   inflating: content/data/segments/9056.wav
#   inflating: content/data/segments/20412.wav
#   inflating: content/data/segments/16923.wav
#   inflating: content/data/segments/24362.wav
#   inflating: content/data/segments/4544.wav
#   inflating: content/data/segments/12114.wav
#   inflating: content/data/segments/7898.wav
#   inflating: content/data/segments/6989.wav
#   inflating: content/data/segments/6664.wav
#   inflating: content/data/segments/19622.wav
#   inflating: content/data/segments/9902.wav
#   inflating: content/data/segments/15142.wav
#   inflating: content/data/segments/21729.wav
#   inflating: content/data/segments/1257.wav
#   inflating: content/data/segments/19915.wav
#   inflating: content/data/segments/23678.wav
#   inflating: content/data/segments/2760.wav
#   inflating: content/data/segments/2087.wav
#   inflating: content/data/segments/11060.wav
#   inflating: content/data/segments/10806.wav
#   inflating: content/data/segments/1662.wav
#   inflating: content/data/segments/21872.wav
#   inflating: content/data/segments/11812.wav
#   inflating: content/data/segments/7574.wav
#   inflating: content/data/segments/23315.wav
#   inflating: content/data/segments/3006.wav
#   inflating: content/data/segments/19677.wav
#   inflating: content/data/segments/9208.wav
#   inflating: content/data/segments/10777.wav
#   inflating: content/data/segments/7438.wav
#   inflating: content/data/segments/8605.wav
#   inflating: content/data/segments/23189.wav
#   inflating: content/data/segments/20935.wav
#   inflating: content/data/segments/17984.wav
#   inflating: content/data/segments/9472.wav
#   inflating: content/data/segments/24595.wav
#   inflating: content/data/segments/8742.wav
#   inflating: content/data/segments/21218.wav
#   inflating: content/data/segments/20324.wav
#   inflating: content/data/segments/18497.wav
#   inflating: content/data/segments/18487.wav
#   inflating: content/data/segments/22542.wav
#   inflating: content/data/segments/20906.wav
#   inflating: content/data/segments/31.wav
#   inflating: content/data/segments/4561.wav
#   inflating: content/data/segments/1792.wav
#   inflating: content/data/segments/689.wav
#   inflating: content/data/segments/8785.wav
#   inflating: content/data/segments/7910.wav
#   inflating: content/data/segments/15032.wav
#   inflating: content/data/segments/13657.wav
#   inflating: content/data/segments/22941.wav
#   inflating: content/data/segments/15355.wav
#   inflating: content/data/segments/20590.wav
#   inflating: content/data/segments/23654.wav
#   inflating: content/data/segments/12402.wav
#   inflating: content/data/segments/7540.wav
#   inflating: content/data/segments/2290.wav
#   inflating: content/data/segments/18340.wav
#   inflating: content/data/segments/9249.wav
#   inflating: content/data/segments/15325.wav
#   inflating: content/data/segments/24544.wav
#   inflating: content/data/segments/19696.wav
#   inflating: content/data/segments/9873.wav
#   inflating: content/data/segments/20136.wav
#   inflating: content/data/segments/18535.wav
#   inflating: content/data/segments/16255.wav
#   inflating: content/data/segments/13721.wav
#   inflating: content/data/segments/2885.wav
#   inflating: content/data/segments/24406.wav
#   inflating: content/data/segments/14397.wav
#   inflating: content/data/segments/17545.wav
#   inflating: content/data/segments/1949.wav
#   inflating: content/data/segments/15486.wav
#   inflating: content/data/segments/6048.wav
#   inflating: content/data/segments/10417.wav
#   inflating: content/data/segments/4835.wav
#   inflating: content/data/segments/3382.wav
#   inflating: content/data/segments/2608.wav
#   inflating: content/data/segments/11472.wav
#   inflating: content/data/segments/24685.wav
#   inflating: content/data/segments/18745.wav
#   inflating: content/data/segments/15246.wav
#   inflating: content/data/segments/1707.wav
#   inflating: content/data/segments/14119.wav
#   inflating: content/data/segments/25717.wav
#   inflating: content/data/segments/3706.wav
#   inflating: content/data/segments/7442.wav
#   inflating: content/data/segments/15869.wav
#   inflating: content/data/segments/11413.wav
#   inflating: content/data/segments/11577.wav
#   inflating: content/data/segments/20113.wav
#   inflating: content/data/segments/6885.wav
#   inflating: content/data/segments/1625.wav
#   inflating: content/data/segments/6874.wav
#   inflating: content/data/segments/3417.wav
#   inflating: content/data/segments/183.wav
#   inflating: content/data/segments/3811.wav
#   inflating: content/data/segments/19082.wav
#   inflating: content/data/segments/2542.wav
#   inflating: content/data/segments/4154.wav
#   inflating: content/data/segments/3924.wav
#   inflating: content/data/segments/15346.wav
#   inflating: content/data/segments/14534.wav
#   inflating: content/data/segments/11699.wav
#   inflating: content/data/segments/22353.wav
#   inflating: content/data/segments/23413.wav
#   inflating: content/data/segments/6538.wav
#   inflating: content/data/segments/20926.wav
#   inflating: content/data/segments/19956.wav
#   inflating: content/data/segments/23569.wav
#   inflating: content/data/segments/23450.wav
#   inflating: content/data/segments/5360.wav
#   inflating: content/data/segments/20762.wav
#   inflating: content/data/segments/5997.wav
#   inflating: content/data/segments/20559.wav
#   inflating: content/data/segments/13818.wav
#   inflating: content/data/segments/3381.wav
#   inflating: content/data/segments/4091.wav
#   inflating: content/data/segments/13783.wav
#   inflating: content/data/segments/4116.wav
#   inflating: content/data/segments/18533.wav
#   inflating: content/data/segments/8479.wav
#   inflating: content/data/segments/8854.wav
#   inflating: content/data/segments/20276.wav
#   inflating: content/data/segments/8093.wav
#   inflating: content/data/segments/22702.wav
#   inflating: content/data/segments/14427.wav
#   inflating: content/data/segments/6279.wav
#   inflating: content/data/segments/22701.wav
#   inflating: content/data/segments/4643.wav
#   inflating: content/data/segments/17364.wav
#   inflating: content/data/segments/15362.wav
#   inflating: content/data/segments/21495.wav
#   inflating: content/data/segments/13095.wav
#   inflating: content/data/segments/17296.wav
#   inflating: content/data/segments/17451.wav
#   inflating: content/data/segments/22623.wav
#   inflating: content/data/segments/8839.wav
#   inflating: content/data/segments/1120.wav
#   inflating: content/data/segments/10283.wav
#   inflating: content/data/segments/18597.wav
#   inflating: content/data/segments/23063.wav
#   inflating: content/data/segments/6839.wav
#   inflating: content/data/segments/16910.wav
#   inflating: content/data/segments/3117.wav
#   inflating: content/data/segments/21968.wav
#   inflating: content/data/segments/16701.wav
#   inflating: content/data/segments/5749.wav
#   inflating: content/data/segments/22174.wav
#   inflating: content/data/segments/25176.wav
#   inflating: content/data/segments/229.wav
#   inflating: content/data/segments/14882.wav
#   inflating: content/data/segments/21842.wav
#   inflating: content/data/segments/6068.wav
#   inflating: content/data/segments/5576.wav
#   inflating: content/data/segments/17039.wav
#   inflating: content/data/segments/12864.wav
#   inflating: content/data/segments/17699.wav
#   inflating: content/data/segments/24935.wav
#   inflating: content/data/segments/4283.wav
#   inflating: content/data/segments/14045.wav
#   inflating: content/data/segments/16104.wav
#   inflating: content/data/segments/24977.wav
#   inflating: content/data/segments/3370.wav
#   inflating: content/data/segments/22653.wav
#   inflating: content/data/segments/2411.wav
#   inflating: content/data/segments/22516.wav
#   inflating: content/data/segments/21284.wav
#   inflating: content/data/segments/19891.wav
#   inflating: content/data/segments/18367.wav
#   inflating: content/data/segments/16183.wav
#   inflating: content/data/segments/19413.wav
#   inflating: content/data/segments/10204.wav
#   inflating: content/data/segments/5309.wav
#   inflating: content/data/segments/2948.wav
#   inflating: content/data/segments/13239.wav
#   inflating: content/data/segments/14876.wav
#   inflating: content/data/segments/10664.wav
#   inflating: content/data/segments/7485.wav
#   inflating: content/data/segments/11875.wav
#   inflating: content/data/segments/25431.wav
#   inflating: content/data/segments/6975.wav
#   inflating: content/data/segments/22070.wav
#   inflating: content/data/segments/1288.wav
#   inflating: content/data/segments/5344.wav
#   inflating: content/data/segments/23564.wav
#   inflating: content/data/segments/21281.wav
#   inflating: content/data/segments/13430.wav
#   inflating: content/data/segments/22416.wav
#   inflating: content/data/segments/17235.wav
#   inflating: content/data/segments/3647.wav
#   inflating: content/data/segments/6261.wav
#   inflating: content/data/segments/10861.wav
#   inflating: content/data/segments/7312.wav
#   inflating: content/data/segments/22464.wav
#   inflating: content/data/segments/4702.wav
#   inflating: content/data/segments/20263.wav
#   inflating: content/data/segments/5878.wav
#   inflating: content/data/segments/23213.wav
#   inflating: content/data/segments/23471.wav
#   inflating: content/data/segments/16900.wav
#   inflating: content/data/segments/5058.wav
#   inflating: content/data/segments/18127.wav
#   inflating: content/data/segments/2795.wav
#   inflating: content/data/segments/10030.wav
#   inflating: content/data/segments/8747.wav
#   inflating: content/data/segments/10842.wav
#   inflating: content/data/segments/3343.wav
#   inflating: content/data/segments/4076.wav
#   inflating: content/data/segments/17363.wav
#   inflating: content/data/segments/8725.wav
#   inflating: content/data/segments/6107.wav
#   inflating: content/data/segments/3621.wav
#   inflating: content/data/segments/15803.wav
#   inflating: content/data/segments/25244.wav
#   inflating: content/data/segments/11644.wav
#   inflating: content/data/segments/7323.wav
#   inflating: content/data/segments/6036.wav
#   inflating: content/data/segments/17690.wav
#   inflating: content/data/segments/9883.wav
#   inflating: content/data/segments/14916.wav
#   inflating: content/data/segments/10535.wav
#   inflating: content/data/segments/1623.wav
#   inflating: content/data/segments/10460.wav
#   inflating: content/data/segments/13494.wav
#   inflating: content/data/segments/2522.wav
#   inflating: content/data/segments/1972.wav
#   inflating: content/data/segments/10519.wav
#   inflating: content/data/segments/2629.wav
#   inflating: content/data/segments/19670.wav
#   inflating: content/data/segments/12800.wav
#   inflating: content/data/segments/3607.wav
#   inflating: content/data/segments/21980.wav
#   inflating: content/data/segments/20360.wav
#   inflating: content/data/segments/16208.wav
#   inflating: content/data/segments/22124.wav
#   inflating: content/data/segments/14928.wav
#   inflating: content/data/segments/3169.wav
#   inflating: content/data/segments/16957.wav
#   inflating: content/data/segments/22155.wav
#   inflating: content/data/segments/13643.wav
#   inflating: content/data/segments/24671.wav
#   inflating: content/data/segments/8431.wav
#   inflating: content/data/segments/8886.wav
#   inflating: content/data/segments/3262.wav
#   inflating: content/data/segments/9401.wav
#   inflating: content/data/segments/20638.wav
#   inflating: content/data/segments/11477.wav
#   inflating: content/data/segments/13272.wav
#   inflating: content/data/segments/11599.wav
#   inflating: content/data/segments/8076.wav
#   inflating: content/data/segments/16161.wav
#   inflating: content/data/segments/2524.wav
#   inflating: content/data/segments/23545.wav
#   inflating: content/data/segments/6399.wav
#   inflating: content/data/segments/10016.wav
#   inflating: content/data/segments/2654.wav
#   inflating: content/data/segments/8457.wav
#   inflating: content/data/segments/20370.wav
#   inflating: content/data/segments/21239.wav
#   inflating: content/data/segments/15179.wav
#   inflating: content/data/segments/18868.wav
#   inflating: content/data/segments/4065.wav
#   inflating: content/data/segments/24256.wav
#   inflating: content/data/segments/21151.wav
#   inflating: content/data/segments/22373.wav
#   inflating: content/data/segments/21965.wav
#   inflating: content/data/segments/23708.wav
#   inflating: content/data/segments/4741.wav
#   inflating: content/data/segments/23756.wav
#   inflating: content/data/segments/21612.wav
#   inflating: content/data/segments/3586.wav
#   inflating: content/data/segments/12867.wav
#   inflating: content/data/segments/13881.wav
#   inflating: content/data/segments/20197.wav
#   inflating: content/data/segments/18271.wav
#   inflating: content/data/segments/18150.wav
#   inflating: content/data/segments/15192.wav
#   inflating: content/data/segments/22299.wav
#   inflating: content/data/segments/14104.wav
#   inflating: content/data/segments/19223.wav
#   inflating: content/data/segments/10948.wav
#   inflating: content/data/segments/20081.wav
#   inflating: content/data/segments/23166.wav
#   inflating: content/data/segments/16222.wav
#   inflating: content/data/segments/7371.wav
#   inflating: content/data/segments/18386.wav
#   inflating: content/data/segments/3289.wav
#   inflating: content/data/segments/24245.wav
#   inflating: content/data/segments/21598.wav
#   inflating: content/data/segments/21661.wav
#   inflating: content/data/segments/21894.wav
#   inflating: content/data/segments/10409.wav
#   inflating: content/data/segments/25113.wav
#   inflating: content/data/segments/16355.wav
#   inflating: content/data/segments/16620.wav
#   inflating: content/data/segments/6739.wav
#   inflating: content/data/segments/4922.wav
#   inflating: content/data/segments/2944.wav
#   inflating: content/data/segments/2054.wav
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.0/519.0 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 kB 46.8 MB/s eta 0:00:00

# %%
import speechbrain as sb
from speechbrain.pretrained import EncoderDecoderASR
import json
import torchaudio
import torch
from torch import nn
from tqdm import tqdm
from collections import Counter

from IPython.display import Audio
from scipy.io import wavfile

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Task 0: Evaluate a pretrained CRDNN model, further finetuned with HVB (5 points)
#
# We will first load a [SpeechBrain CRDNN model pretrained on LibriSpeech](https://huggingface.co/speechbrain/asr-crdnn-rnnlm-librispeech). SpeechBrain has some utils with built-in options to source pre-trained models from a repository on HuggingFace.
#
# In Task 0, you will first load this pretrained CRDNN model from HuggingFace and use it for inference on the first 500 examples from `test_manifest.json` (included within `hvb.zip` you have already downloaded earlier). Subsequently, you will fine tune this model on the HVB training dataset before reevaluating on the test examples and note the difference in performance.

# %%
crdnn = EncoderDecoderASR.from_hparams(
    source='speechbrain/asr-crdnn-rnnlm-librispeech',
    savedir='asr-crdnn-rnnlm-librispeech',
    run_opts={'device': 'cuda'}
)

# %% [markdown]
# The manifests we prepared to use with SpeechBrain are jsons with the structure
# ```
# {
#     "15748": {
#         "wav": "/content/data/segments/15748.wav",
#         "length": 1.86,
#         "words": "WHAT DAY WOULD YOU LIKE FOR YOUR APPOINTMENT"
#     },
#     ...
# }
# ```
#
# We first load them and define a function to batch them into a format that our `EncoderDecoderASR` object can ingest:

# %%
TEST_SIZE = 500 # for faster processing

with open('/content/content/data/test_manifest.json', 'r') as f:
    test_manifest = json.load(f)
test_manifest = {k: v for k, v in list(test_manifest.items())[:TEST_SIZE]}


def batchify(manifest, batch_size):
    keys = list(manifest.keys())
    wav_paths = list(map(lambda x: '/content'+x['wav'], manifest.values()))
    iterable = zip(keys, wav_paths)
    num_examples = len(manifest)
    for i in range(0, num_examples, batch_size):
        batch_wavs = nn.utils.rnn.pad_sequence([
            torchaudio.load(path)[0].squeeze(0)
            for path in wav_paths[i:min(i + batch_size, num_examples)]
        ], batch_first=True)
        batch_keys = keys[i:min(i + batch_size, num_examples)]
        batch_wav_lens = torch.tensor([
            manifest[key]['length'] for key in batch_keys
        ])
        batch_wav_lens = batch_wav_lens / batch_wav_lens.max()
        yield batch_keys, batch_wavs, batch_wav_lens

# %% [markdown]
# Next, we feed our test examples through the pretrained ASR model:

# %%
true_dict = {key: test_manifest[key]['words'] for key in test_manifest}

def inference(model, test_manifest, batch_size=8):
    torch.cuda.empty_cache()
    pred_dict = {}
    for keys, wavs, wav_lens in tqdm(batchify(test_manifest, batch_size), total=round(len(test_manifest) / batch_size + 0.5)):
        transcriptions, _ = model.transcribe_batch(wavs.to(device), wav_lens.to(device))
        for key, transcription in zip(keys, transcriptions):
            pred_dict[key] = transcription
    return pred_dict

pred_dict = inference(crdnn, test_manifest)
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# 100%|██████████| 63/63 [03:56<00:00,  3.76s/it]

# %% [markdown]
# ## Q1: Evaluate WER of pretrained model predictions (2 points)

# %% [markdown]
# Check the word error rate on the first 200 test instances in `test_manifest.json`. Note that we want WERs, so we need to split our transcripts into lists of words.
#
# You don't need to implement anything new here. Just follow along and ensure you can run the code to obtain WER on the results you just generated.

# %%
# this data structure stores WER information we use later.
details_by_utterance = sb.utils.edit_distance.wer_details_by_utterance(
    {k: v.split() for k, v in true_dict.items()},
    {k: v.split() for k, v in pred_dict.items()},
)

# %%
# word error rate (WER) summary using data structure we just created
sb.utils.edit_distance.wer_summary(details_by_utterance)
# Out:
# {'WER': 75.84080717488789,
#  'SER': 87.8,
#  'num_edits': 2706,
#  'num_scored_tokens': 3568,
#  'num_erraneous_sents': 439,
#  'num_scored_sents': 500,
#  'num_absent_sents': 0,
#  'num_ref_sents': 500,
#  'insertions': 1127,
#  'deletions': 307,
#  'substitutions': 1272}

# %% [markdown]
# What is the WER value you obtain? Write it down in `README.txt` that you will upload on Moodle, along with your Colab notebook.
#
# We expect WER of this pretrained system to be somewhat high on HVB data (around 72%+ WER). That is really quite high! Note that we already re-sampled the audio to 16kHz to make the HVB audio features more similar to the training inputs of the pre-trained model.
#
# Often times ASR errors have specific error modes or correlations -- let's see if we can understand where our pretrained system is failing on HVB data. We can start to investigate where our system is making mistakes by checking some of the top missed utterances.

# %%
def summarize(detail_dict, true_dict, pred_dict):
    print(f"{detail_dict['key']}: {detail_dict['WER']}")
    print(f"\tTrue: {true_dict[detail_dict['key']]}")
    print(f"\tPred: {pred_dict[detail_dict['key']]}")

for wer_dict in sb.utils.edit_distance.top_wer_utts(details_by_utterance, 10)[0]:
    summarize(wer_dict, true_dict, pred_dict)
# Out:
# 3015: 6900.0
# 	True: ZERO
# 	Pred: AIN'T IT OAT OAT OAT OAT OAK OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT OAT
# 5788: 2633.3333333333335
# 	True: YOU AS WELL
# 	Pred: YOU'RE THE WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WEST WE
# 1130: 2400.0
# 	True: ALRIGHT
# 	Pred: RIPE RIGHT RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE RIPE
# 8731: 2100.0
# 	True: ALRIGHT
# 	Pred: HE ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED ARRAYED
# 8211: 1466.6666666666667
# 	True: HMM TWO FIFTEEN
# 	Pred: YOU AIN'T PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT PAINT
# 6150: 1275.0
# 	True: MY NAME IS ELIZABETH
# 	Pred: ELIZABETH SAID ELIZABETH IT'S IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT'S IT IT
# 21066: 1250.0
# 	True: FIRST STREET
# 	Pred: BURST DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT DRIFT
# 12742: 1033.3333333333333
# 	True: NO THAT'S IT
# 	Pred: NOW I DIDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN'T I COULDN
# 5040: 966.6666666666666
# 	True: OKAY ONE HUNDRED AND THIRTY <UNK>
# 	Pred: ONE HUNDRED THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRTY THIRT
# 8336: 850.0
# 	True: TWO SEVENTEEN
# 	Pred: FELT IT THROBBED IT IT FELT IT THROBBED IT IT FELT IT THROBBED IT IT FELT IT

# %% [markdown]
# Seems that our predictions keep outputting the same word over and over. Let's see why.

# %% [markdown]
# Select some examples the model wrongly predicts, and try to build a hypothesis around what in the data is associated with the model making mistakes. Examples of mistake types include:
# - Repeated wrong word
# - A few correct words but clearly wrong transcript
#
# Give examples of at least 3 audio files and different kinds of errors you have identified in these audio files. Add this to `README.txt`.

# %% [markdown]
# Here's a code snippet to help you get started.

# %%
test_manifest[example['key']]['wav']]
# Out:
# '/content/data/segments/15748.wav'

# %%
example = details_by_utterance[0]
summarize(example, true_dict, pred_dict)
Audio('/content'+test_manifest[example['key']]['wav'])
# Out:
# 15748: 37.5
# 	True: WHAT DAY WOULD YOU LIKE FOR YOUR APPOINTMENT
# 	Pred: WHAT DAY WOULD YOU LIKELY APPOINT APPOINTMENT
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# (Hint: In our initial checks, poor audio quality seems to be associated with repeated word errors.)

# %% [markdown]
# ## Q2: Finetune the pretrained CRDNN model (2 points)

# %% [markdown]
# The performance of this pretrained model is disappointing. However, the model was trained on a different data domain than call-center transcripts as in HVB. To see if we can derive better performance on our dataset, we fine-tune the pretrained model with HVB training data and test it. For this experiment, you won't need to modify it much. Just get training working, and you can try adjusting some training or decoding parameters as you like. The key thing to learn here is simply developing an understanding of how things work when finetuning on a new corpus using SpeechBrain. (This is a state-of-the-art approach to building and adjusting ASR models that might be used in industry projects.)
#
# We've set up the training script, experiment yaml, and inference yaml for you, but we encourage you to take a look at how it works (and most importantly what a neat ML experiment yaml file looks like). Training this model for 2 epochs on Colab GPUs should take around **1.5 hours**.
#
# The model will save checkpoints during training which you can specify for use during inference / testing below. That means you should be able to use a fine-tuned version of the model, even if you don't wait the full time for the model to completely train. It is okay to submit the homework with your fine tuning model partially trained, but not 2 full epochs.

# %%
# this downloads the training and config files for our fine tuning setup
# !gdown 1v_3Kl8OrUd6_1_D0ZGoYVFEuOKhZ7YMo # train.py
# !gdown 17cQIpx5kLLMCD23EDaE0EYg2E9LPqMCF # train.yaml
# !gdown 1CWYOD2PC97gXguW4krc9122HKAraHkYS # inference.yaml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1v_3Kl8OrUd6_1_D0ZGoYVFEuOKhZ7YMo
# To: /content/train.py
# 100% 18.3k/18.3k [00:00<00:00, 28.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17cQIpx5kLLMCD23EDaE0EYg2E9LPqMCF
# To: /content/train.yaml
# 100% 12.1k/12.1k [00:00<00:00, 17.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CWYOD2PC97gXguW4krc9122HKAraHkYS
# To: /content/inference.yaml
# 100% 4.96k/4.96k [00:00<00:00, 9.66MB/s]

# %% [markdown]
# **Finetuning with HVB data**:
#
# There are two files you've just downloaded which specify the architecture to train, and the main training loop for improving the neural net ASR system.
#
# - `train.yaml` is the yaml config file SpeechBrain uses to specify both the network / ASR system architecture, as well as the parameters of training procedures, loss functions, datasets, etc. This is a good starting point for understanding the architecture of the ASR system you're working with. Note that you are not able to modify much about the ASR network architecture as it needs to match what we load from file. You can adjust things like loss function weights, learning rate, and training time to adjust the fine tuning setup.
# - `train.py` specifies the main training loop for fitting the acoustic model. You do not need to modify this file.
#
# Edit the training yaml file and run the training loop as shown below. Finetune with modified hyperparameters that worked best for you. Copy/paste train loss, valid loss, valid CER and valid WER from your training output in `README.txt`, along with the epoch number. (With using `train.yaml` as-is, we obtained training and validation loss < 1.75 after epoch 1.)

# %%
# !pip install hyperpyyaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.9/dist-packages (1.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from hyperpyyaml) (6.0)
# Requirement already satisfied: ruamel.yaml>=0.17.8 in /usr/local/lib/python3.9/dist-packages (from hyperpyyaml) (0.17.21)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from ruamel.yaml>=0.17.8->hyperpyyaml) (0.2.7)

# %%
import yaml

with open("train.yaml", "r") as stream:
    try:
        print(yaml.safe_load(stream))
    except yaml.YAMLError as exc:
        print(exc)
# Out:
# could not determine a constructor for the tag '!apply:torch.manual_seed'
#   in "train.yaml", line 14, column 13

# %%
torch.cuda.empty_cache()

# !python train.py train.yaml --batch_size=4
# OOM on batch_size=5
# Out:
# Downloading http://www.openslr.org/resources/28/rirs_noises.zip to ./data/rirs_noises.zip
# rirs_noises.zip: 1.31GB [01:35, 13.8MB/s]
# Extracting ./data/rirs_noises.zip to ./data
# Traceback (most recent call last):
#   File "/content/train.py", line 417, in <module>
#     hparams = load_hyperpyyaml(fin, overrides)
#   File "/usr/local/lib/python3.9/dist-packages/hyperpyyaml/core.py", line 188, in load_hyperpyyaml
#     hparams = yaml.load(yaml_stream, Loader=loader)
#   File "/usr/local/lib/python3.9/dist-packages/yaml/__init__.py", line 81, in load
#     return loader.get_single_data()
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 121, in get_single_data
#     return self.construct_document(node)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 126, in construct_document
#     data = self.construct_object(node)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 154, in construct_object
#     data = self.construct_non_recursive_object(node)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 196, in construct_non_recursive_object
#     for _dummy in generator:
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 674, in construct_yaml_map
#     value = self.construct_mapping(node)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 445, in construct_mapping
#     return BaseConstructor.construct_mapping(self, node, deep=deep)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 261, in construct_mapping
#     value = self.construct_object(value_node, deep=deep)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 154, in construct_object
#     data = self.construct_non_recursive_object(node)
#   File "/usr/local/lib/python3.9/dist-packages/ruamel/yaml/constructor.py", line 191, in construct_non_recursive_object
#     data = constructor(self, tag_suffix, node)
#   File "/usr/local/lib/python3.9/dist-packages/hyperpyyaml/core.py", line 481, in _construct_object
#     return callable_(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/speechbrain/lobes/models/CRDNN.py", line 175, in __init__
#     self.append(
#   File "/usr/local/lib/python3.9/dist-packages/speechbrain/nnet/containers.py", line 112, in append
#     layer = layer(*args, input_shape=input_shape, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/speechbrain/nnet/RNN.py", line 241, in __init__
#     rnn_init(self.rnn)
#   File "/usr/local/lib/python3.9/dist-packages/speechbrain/nnet/RNN.py", line 1610, in rnn_init
#     nn.init.orthogonal_(param)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/init.py", line 484, in orthogonal_
#     q, r = torch.linalg.qr(flattened)
# KeyboardInterrupt
# ^C

# %% [markdown]
# ## Q3: Evaluate your finetuned model (1 point)

# %% [markdown]
# To run inference, you need to use a different yaml to be compatible with the `EncoderDecoderASR` class.
#
# NOTE: You need to set your checkpoint path in a few locations to make this work. Be careful your paths are set before other debugging if things aren't working (e.g. trying to download from HuggingFace)
#
# To get inference working there are three steps:
# 1. Note the directory that your checkpoints are saved in (under `./results/CRDNN_BPE_960h_LM/2602/save/{your ckpt here}`)
# 2. Paste this directory into the ckptdir entry in `inference.yaml`
# 3. Paste this directory after the `ckpt_path = ` in the below cell.
#
# You can then use the same inference procedure as in Q1.
# NOTE: set the `ckpt_path` below AND change the path in `inference.yaml` (by modifying `ckptdir` to point to the desired checkpoint) before or after it is copied into your checkpoint path.

# %%
ckpt_path = "/content/results/CRDNN_BPE_960h_LM/2602/save/CKPT+2022-05-09+17-22-55+00"
# !cp inference.yaml {ckpt_path}
# Out:
# cp: cannot create regular file '/content/results/CRDNN_BPE_960h_LM/2602/save/CKPT+2022-05-09+17-22-55+00': No such file or directory

# %% [markdown]
# Evaluate your finetuned model on the first 50 test sentences in `test_manifest.json`. Generate predictions by setting up a model object, and calling `inference()`. Remember your checkpoint paths must be set correctly in the copy of inference.yaml read to run inference. For this step simply populate pred_dict with inferences from your test subset. Write down the WER in `README.txt`. Also compute the WER from the pretrained model for this test subset of size 50 and write it down in `README.txt`.
#
# NOTE: Running inference on ~50 utterances might require ~15 minutes of computation on a Colab CPU. The code below uses CPU inference as we could not get checkpoint-loaded DNNs to work with SpeechBrain's inference on the GPU (you are free to try this).

# %%
device = 'cpu'
our_model = EncoderDecoderASR.from_hparams(
    source=ckpt_path,
    hparams_file='inference.yaml',
    savedir="our_ckpt",
    run_opts={'device': device}
)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# <ipython-input-19-5ef8cbd04d79> in <cell line: 2>()
#       1 device = 'cpu'
# ----> 2 our_model = EncoderDecoderASR.from_hparams(
#       3     source=ckpt_path,
#       4     hparams_file='inference.yaml',
#       5     savedir="our_ckpt",
#
# /usr/local/lib/python3.9/dist-packages/speechbrain/pretrained/interfaces.py in from_hparams(cls, source, hparams_file, pymodule_file, overrides, savedir, use_auth_token, revision, download_only, **kwargs)
#     365             clsname = cls.__name__
#     366             savedir = f"./pretrained_models/{clsname}-{hashlib.md5(source.encode('UTF-8', errors='replace')).hexdigest()}"
# --> 367         hparams_local_path = fetch(
#     368             filename=hparams_file,
#     369             source=source,
#
# /usr/local/lib/python3.9/dist-packages/speechbrain/pretrained/fetching.py in fetch(filename, source, savedir, overwrite, save_filename, use_auth_token, revision)
#     118         logger.info(MSG)
#     119         try:
# --> 120             fetched_file = huggingface_hub.hf_hub_download(
#     121                 repo_id=source,
#     122                 filename=filename,
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     110         ):
#     111             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 112                 validate_repo_id(arg_value)
#     113
#     114             elif arg_name == "token" and arg_value is not None:
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_validators.py in validate_repo_id(repo_id)
#     158
#     159     if repo_id.count("/") > 1:
# --> 160         raise HFValidationError(
#     161             "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     162             f" '{repo_id}'. Use `repo_type` argument if needed."
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/results/CRDNN_BPE_960h_LM/2602/save/CKPT+2022-05-09+17-22-55+00'. Use `repo_type` argument if needed.

# %%
TEST_SIZE = 50 # for faster processing
with open('/content/content/data/test_manifest.json', 'r') as f:
    test_manifest = json.load(f)
test_manifest = {k: v for k, v in list(test_manifest.items())[:TEST_SIZE]}

pred_dict = inference(our_model.to(device), test_manifest)

# %% [markdown]
# # Task 1: Train a sentiment detection model (20 points)

# %% [markdown]
# Apart from the audio files and transcriptions, the HVB corpus also comes with annotations for intent, sentiment/emotion and dialog actions. Use the command below to download `transcript.zip`.

# %%
# !gdown 1-s2e8dZYSjhVgfo_TL0V_89RZVhGnZ1Y
# !unzip -q transcript.zip

# !gdown 1ChdI1XyhmGq9z8Y8M38yXPMob6oPRqPO  #train.txt
# !gdown 10w15DnUbJcQRBSZWP03qjM6Oq8l7WSVQ  #dev.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-s2e8dZYSjhVgfo_TL0V_89RZVhGnZ1Y
# To: /content/transcript.zip
# 100% 4.08M/4.08M [00:00<00:00, 102MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ChdI1XyhmGq9z8Y8M38yXPMob6oPRqPO
# To: /content/train.txt
# 100% 30.5k/30.5k [00:00<00:00, 41.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10w15DnUbJcQRBSZWP03qjM6Oq8l7WSVQ
# To: /content/dev.txt
# 100% 12.3k/12.3k [00:00<00:00, 23.9MB/s]

# %%
with open('transcript/370981f1f0254ebc.json', 'r') as f:
  fl=f.read()

# %%
import json
f = open('transcript/370981f1f0254ebc.json')
data = json.load(f)
data[0]
# Out:
# {'channel_index': 2,
#  'dialog_acts': ['gridspace_greeting'],
#  'duration_ms': 2970,
#  'emotion': {'neutral': 0.3537469506263733,
#   'negative': 0.03589286655187607,
#   'positive': 0.6103601455688477},
#  'human_transcript': 'hello this is harper valley national bank my name is michael',
#  'index': 1,
#  'offset_ms': 6020,
#  'speaker_role': 'agent',
#  'start_ms': 3970,
#  'start_timestamp_ms': 1591055856446,
#  'transcript': 'hello this is harper valley national bank my name is michael',
#  'word_durations_ms': [330, 180, 120, 270, 300, 390, 270, 150, 150, 90, 450],
#  'word_offsets_ms': [0,
#   600,
#   780,
#   900,
#   1170,
#   1470,
#   1860,
#   2130,
#   2280,
#   2430,
#   2520]}

# %% [markdown]
# Each transcript json file within `/content/transcript/` refers to a conversation with a list of utterances. Each segment (utterance) is associated with a json object and one of its keys is labeled as "emotion" that maps to three probability values associated with positive, negative and neutral sentiments. You can consider the sentiment with maximum probability to be the ground-truth label for each utterance.
#
# For this task, you will write new code to create a sentiment classification model for HVB utterances. Here are the various steps:
# - Create train and dev splits from `train.txt` and `dev.txt` downloaded in the code cell above. To understand the format in `train.txt` (and `dev.txt`), consider a line in  `train.txt`: *010d38f5ada54e0d:1,2,3,4,5,6,7,8*. This refers to conversation-ID 010d38f5ada54e0d with eight utterances appearing sequentially within the file `/content/transcript/010d38f5ada54e0d.json`. These utterances are numbered by the field "index" in the json file. Similarly interpret the lines in `dev.txt`. Use these text files (`train.txt` and `dev.txt`) to create train and dev sets and extract the relevant metadata ("emotion") you need from the respective transcript json files.
# - Load the pretrained CRDNN Librispeech model as in Task 0 and extract the encoder.
# - Add a linear layer mapping the encoding of the audio signal to a prediction of the underlying sentiment. This will be randomly initialized.
# - Train both the new linear layer and all the pretrained encoder layers using a cross-entropy loss with the reference emotion labels derived as described at the top of this cell.
# - Evaluate your trained sentiment detection model on utterances listed in `dev.txt` and compute overall accuracy for sentiment prediction.
# - Write down the accuracy you obtained in `README.txt`.

# %% [markdown]
# ## Rough Score Breakdown
#
# ---
#
# 1. Data preprocessing (4 points)
# 2. Loading the CRDNN model and extracting the encoder layers (6 points)
# 3. Adding a linear layer + training the model (7 points)
# 4. Obtaining accuracies similar to or better than our solution code (3 points)

# %%
import re
def create_dataset(file_name_str):
  file1 = open(file_name_str,"r")
  x=file1.read().split('\n')
  y1=[i.split(':')[0] for i in x ]
  y2=[list(map(int,re.findall(r'\d+', i.split(':')[-1]))) for i in x ]
  train_dict=dict(zip(y1,y2))
  transcr_list=[]
  emotion_list=[]
  for key in train_dict.keys():
    fname='transcript/'+key+'.json'
    f = open('transcript/370981f1f0254ebc.json')
    data_dic = json.load(f)
    for data in data_dic:
      if data['index'] in train_dict[key]:
        transcr_list.append(data['transcript'])
        emotion_list.append(list(data['emotion'].values()))
  return dict(zip(transcr_list,emotion_list))

# %%
create_dataset("train.txt")
# Out:
# {'hello this is harper valley national bank my name is michael': [0.3537469506263733,
#   0.03589286655187607,
#   0.6103601455688477],
#  'how can i help you today': [0.352674663066864,
#   0.06029738858342171,
#   0.587027907371521],
#  '[noise]': [1.0, 0.0, 0.0],
#  '[noise] hi my name is elizabeth brown i need a new checkbook': [0.32787075638771057,
#   0.04341552034020424,
#   0.6287136673927307],
#  'what is your address': [0.5000655651092529,
#   0.3527262210845947,
#   0.14720825850963593],
#  'okay': [0.5097575783729553, 0.2189798504114151, 0.27126264572143555],
#  'my address is eight five six first street': [0.47416213154792786,
#   0.43734416365623474,
#   0.088493712246418],
#  'uh': [0.5228667259216309, 0.29485175013542175, 0.1822814792394638],
#  'mm hmm': [0.5318920016288757, 0.31008899211883545, 0.1580190360546112],
#  'forrest ranch': [0.43634673953056335,
#   0.11246293783187866,
#   0.451190322637558],
#  'alright': [0.5168510675430298, 0.24006950855255127, 0.24307942390441895],
#  'oregon': [0.5262944102287292, 0.26111674308776855, 0.21258880198001862],
#  'eight two four five five': [0.5957316160202026,
#   0.17710202932357788,
#   0.2271662950515747],
#  '[laughter]': [1.0, 0.0, 0.0],
#  'okay is there anything else i can help you with': [0.3273395001888275,
#   0.04454446956515312,
#   0.6281160116195679],
#  'no thank you': [0.36750414967536926, 0.11526410281658173, 0.517231822013855],
#  'thank you for calling have a great day': [0.305245965719223,
#   0.025679877027869225,
#   0.6690741181373596]}

# %%
train_dataset
# Out:
# {'hello this is harper valley national bank my name is michael': [0.3537469506263733,
#   0.03589286655187607,
#   0.6103601455688477],
#  'how can i help you today': [0.352674663066864,
#   0.06029738858342171,
#   0.587027907371521],
#  '[noise]': [1.0, 0.0, 0.0],
#  '[noise] hi my name is elizabeth brown i need a new checkbook': [0.32787075638771057,
#   0.04341552034020424,
#   0.6287136673927307],
#  'what is your address': [0.5000655651092529,
#   0.3527262210845947,
#   0.14720825850963593],
#  'okay': [0.5097575783729553, 0.2189798504114151, 0.27126264572143555],
#  'my address is eight five six first street': [0.47416213154792786,
#   0.43734416365623474,
#   0.088493712246418],
#  'uh': [0.5228667259216309, 0.29485175013542175, 0.1822814792394638],
#  'mm hmm': [0.5318920016288757, 0.31008899211883545, 0.1580190360546112],
#  'forrest ranch': [0.43634673953056335,
#   0.11246293783187866,
#   0.451190322637558],
#  'alright': [0.5168510675430298, 0.24006950855255127, 0.24307942390441895],
#  'oregon': [0.5262944102287292, 0.26111674308776855, 0.21258880198001862],
#  'eight two four five five': [0.5957316160202026,
#   0.17710202932357788,
#   0.2271662950515747],
#  '[laughter]': [1.0, 0.0, 0.0],
#  'okay is there anything else i can help you with': [0.3273395001888275,
#   0.04454446956515312,
#   0.6281160116195679],
#  'no thank you': [0.36750414967536926, 0.11526410281658173, 0.517231822013855],
#  'thank you for calling have a great day': [0.305245965719223,
#   0.025679877027869225,
#   0.6690741181373596]}

# %% [markdown]
# # Extra Credit: Use Whisper's pretrained model to evaluate HVB (5 points)

# %% [markdown]
# Write code to evaluate [Whisper's **small** model](https://github.com/openai/whisper/blob/main/model-card.md) on the first 200 test utterances in `test_manifest.json` that you used in Q1 of Task 0. Compute the WER with predictions from Whisper and add it to `README.txt`.

# %%
##############################################################
#### YOUR EVALUATION CODE USING Whisper-small GOES BELOW #####
##############################################################
